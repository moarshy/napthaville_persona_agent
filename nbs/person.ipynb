# %%
from dotenv import load_dotenv
load_dotenv()
import logging
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

# %%
from napthaville_environment.run import run as env_run
from napthaville_memory.run import run as memory_run
import json
from pathlib import Path
import math
from operator import itemgetter

# %%
from napthaville_persona_agent.persona.persona import Persona
from napthaville_persona_agent.persona.cognitive_modules.plan import plan, _long_term_planning, _determine_action, _choose_retrieved, _should_react
from napthaville_persona_agent.persona.memory.scratch import Scratch

# %%
env_deployment_path = "/Users/arshath/play/napthaville_persona_agent/napthaville_environment/configs/deployment.json"
env_deployment = json.load(open(env_deployment_path))
env_deployment = env_deployment[0]
env_deployment["node"] = {
        "ip": "localhost",
        "user_communication_port": 7001,
        "user_communication_protocol": "http"
    }

# %%
test_memory_isabella_dir = Path("/Users/arshath/play/napthaville_persona_agent/test_data/July1_the_ville_isabella_maria_klaus-step-3-19/personas/Isabella Rodriguez/bootstrap_memory")
test_memory_maria_dir = Path("/Users/arshath/play/napthaville_persona_agent/test_data/July1_the_ville_isabella_maria_klaus-step-3-19/personas/Maria Lopez/bootstrap_memory")
test_memory_klaus_dir = Path("/Users/arshath/play/napthaville_persona_agent/test_data/July1_the_ville_isabella_maria_klaus-step-3-19/personas/Klaus Mueller/bootstrap_memory")

memory_deployment_path = "/Users/arshath/play/napthaville_persona_agent/napthaville_memory/configs/deployment.json"
memory_deployment = json.load(open(memory_deployment_path))
memory_deployment = memory_deployment[0]
memory_deployment["node"] = {
    "ip": "localhost",
    "user_communication_port": 7001,
    "user_communication_protocol": "http"
}

# %% [markdown]
# ### initialize maze

# %%
inputs = {
    "function_name": "init",
    "function_input_data": {}
}
module_run = {"inputs": inputs, "deployment": env_deployment}
result = await env_run(module_run)
print(result)

# %% [markdown]
# ### Initialize memory for isabella rodriguez, maria and klaus

# %%
inputs = {
    "function_name": "init",
    "function_input_data": {}
}
module_run = {"inputs": inputs, "deployment": memory_deployment}
result = await memory_run(module_run)

# %%
# spatial memory add
spatial_data = json.load(open(test_memory_isabella_dir / "spatial_memory.json"))
spatial_add = {
    "inputs": {
        "function_name": "set_memory",
        "function_input_data": {
            "memory_type": "spatial",
            "operation": "add",
            "data": json.dumps(spatial_data),
            "persona_name": "Isabella Rodriguez"
        }
    },
    "deployment": memory_deployment
}
result = await memory_run(spatial_add)
print(result)

# %%
# scratch memory add
scratch_data = json.load(open(test_memory_isabella_dir / "scratch.json"))
scratch_add = {
    "inputs": {
        "function_name": "set_memory",
        "function_input_data": {
            "memory_type": "scratch",
            "operation": "add",
            "data": json.dumps(scratch_data),
            "persona_name": "Isabella Rodriguez"
        }
    },
    "deployment": memory_deployment
}
result = await memory_run(scratch_add)
print(result)

# %%
for subtype in ["embeddings", "nodes", "kw_strength"]:
    with open(test_memory_isabella_dir / "associative_memory" / f"{subtype}.json") as f:
        assoc_data = json.load(f)
    
    # Add associative memory
    assoc_add = {
        "inputs": {
            "function_name": "set_memory",
            "function_input_data": {
                "memory_type": "associative",
                "subtype": subtype,
                "operation": "add",
                "data": json.dumps(assoc_data),
                "persona_name": "Isabella Rodriguez"
            }
        },
        "deployment": memory_deployment
    }
    result = await memory_run(assoc_add)
    print(result)

# %%
# spatial memory add 
spatial_data = json.load(open(test_memory_klaus_dir / "spatial_memory.json"))
spatial_add = {
    "inputs": {
        "function_name": "set_memory",
        "function_input_data": {
            "memory_type": "spatial",
            "operation": "add",
            "data": json.dumps(spatial_data),
            "persona_name": "Klaus Mueller"
        }
    },
    "deployment": memory_deployment
}
result = await memory_run(spatial_add)
print(result)

# %%
# scratch memory add
scratch_data = json.load(open(test_memory_klaus_dir / "scratch.json"))
scratch_add = {
    "inputs": {
        "function_name": "set_memory",
        "function_input_data": {
            "memory_type": "scratch",
            "operation": "add",
            "data": json.dumps(scratch_data),
            "persona_name": "Klaus Mueller"
        }
    },
    "deployment": memory_deployment
}
result = await memory_run(scratch_add)
print(result)

# %%
for subtype in ["embeddings", "nodes", "kw_strength"]:
    with open(test_memory_klaus_dir / "associative_memory" / f"{subtype}.json") as f:
        assoc_data = json.load(f)
    
    # Add associative memory
    assoc_add = {
        "inputs": {
            "function_name": "set_memory",
            "function_input_data": {
                "memory_type": "associative",
                "subtype": subtype,
                "operation": "add",
                "data": json.dumps(assoc_data),
                "persona_name": "Klaus Mueller"
            }
        },
        "deployment": memory_deployment
    }
    result = await memory_run(assoc_add)
    print(result)

# %%
# spatial memory add 
spatial_data = json.load(open(test_memory_maria_dir / "spatial_memory.json"))
spatial_add = {
    "inputs": {
        "function_name": "set_memory",
        "function_input_data": {
            "memory_type": "spatial",
            "operation": "add",
            "data": json.dumps(spatial_data),
            "persona_name": "Maria Lopez"
        }
    },
    "deployment": memory_deployment
}
result = await memory_run(spatial_add)
print(result)

# %%
# scratch memory add
scratch_data = json.load(open(test_memory_maria_dir / "scratch.json"))
scratch_add = {
    "inputs": {
        "function_name": "set_memory",
        "function_input_data": {
            "memory_type": "scratch",
            "operation": "add",
            "data": json.dumps(scratch_data),
            "persona_name": "Maria Lopez"
        }
    },
    "deployment": memory_deployment
}
result = await memory_run(scratch_add)
print(result)

# %%
for subtype in ["embeddings", "nodes", "kw_strength"]:
    with open(test_memory_maria_dir / "associative_memory" / f"{subtype}.json") as f:
        assoc_data = json.load(f)
    
    # Add associative memory
    assoc_add = {
        "inputs": {
            "function_name": "set_memory",
            "function_input_data": {
                "memory_type": "associative",
                "subtype": subtype,
                "operation": "add",
                "data": json.dumps(assoc_data),
                "persona_name": "Maria Lopez"
            }
        },
        "deployment": memory_deployment
    }
    result = await memory_run(assoc_add)
    print(result)

# %% [markdown]
# ### Start testing persona

# %%
isabella = Persona(
    "Isabella Rodriguez", 
    memory_deployment=memory_deployment,
    maze_deployment=env_deployment
)

maria = Persona(
    "Maria Lopez", 
    memory_deployment=memory_deployment,
    maze_deployment=env_deployment
)

klaus = Persona(
    "Klaus Mueller", 
    memory_deployment=memory_deployment,
    maze_deployment=env_deployment
)

# %%
await isabella.load_memory()
await maria.load_memory()
await klaus.load_memory()
# Out:
# 2025-03-02 14:52:31,027 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:31,055 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:31,079 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:31,286 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:31,404 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:31,521 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:31,534 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:31,548 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:31,723 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:31,834 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:31,961 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:31,977 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:31,993 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:32,172 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:32,288 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001

# %%
perceive_response = await isabella.perceive()
perceive_response

# %%
retrieve_response = isabella.retrieve(perceive_response)
retrieve_response

# %%
_long_term_planning(isabella, new_day=True)

# %%
maze_data = isabella.perceive_maze_data

# %%
_determine_action(isabella, maze_data)

# %%
_choose_retrieved(isabella, retrieve_response)

# %%
isabella.scratch.name = "Isabella Rodriguez"

# %%
await isabella.save_memory()
# Out:
# 2025-03-02 14:52:45,493 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:45,526 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:45,561 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:45,567 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:45,686 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001

# %%
await isabella.load_memory()
# Out:
# 2025-03-02 14:52:46,247 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:46,270 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:46,292 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:46,497 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001
# 2025-03-02 14:52:46,612 - naptha_sdk.storage.storage_client - INFO - Storage Provider URL: http://localhost:7001

# %%
isabella.scratch.name
# Out:
# 'Isabella Rodriguez'

# %%
# get scratch memory for klaus and maria
scratch_add = {
    "inputs": {
        "function_name": "get_memory",
        "function_input_data": {
            "memory_type": "scratch",
            "persona_name": "Klaus Mueller"
        }
    },
    "deployment": memory_deployment
}
result = await memory_run(scratch_add)
klaus_scratch = json.loads(json.loads(result['data'][0]['memory_data'])[0]['data'])

# %%
# get scratch memory for klaus and maria
scratch_add = {
    "inputs": {
        "function_name": "get_memory",
        "function_input_data": {
            "memory_type": "scratch",
            "persona_name": "Maria Lopez"
        }
    },
    "deployment": memory_deployment
}
result = await memory_run(scratch_add)
maria_scratch = json.loads(json.loads(result['data'][0]['memory_data'])[0]['data'])

# %%
persona_scratches = {
    "Klaus Mueller": Scratch(klaus_scratch),
    "Maria Lopez": Scratch(maria_scratch)
}
